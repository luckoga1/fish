# %%
#hide
# !pip install -Uqq fastbook
import fastbook
fastbook.setup_book()

# %%
#hide
from fastbook import *
from fastai.vision.widgets import *

# %%
#!pip install voila
#!jupyter serverextension enable --sys-prefix voila

# %% [markdown]
# Esse é um classificador de Peixes!
#
# Nesse teste de Machine Learning, conseguimos realizar um classificador de peixes (piranha, pirarucu, sardinha, tambaqui e tucunaré). Usando um modelo de Resnet34, nossa máquina de detecção funciona apenas com essas cinco categorias de peixes.
#
# English
#
# In this Machine Learning test, we managed to perform a fish classifier (piranha, pirarucu, sardines, tambaqui and tucunaré). Using a model of Resnet34, our detection machine works only with these five categories of fish.
#
# Français
# Dans ce test d'apprentissage automatique, nous avons réussi à effectuer un classificateur de poisson (piranha, pirarucu, sardines, tambaqui et tucunaré). Utilisant un modèle de Resnet34, notre machine de détection fonctionne uniquement avec ces cinq catégories de poissons.

# %%
path = Path()
learn_inf = load_learner(path/'export.pkl', cpu=True)
btn_upload = widgets.FileUpload()
out_pl = widgets.Output()
lbl_pred = widgets.Label()

# %%
# test def on_click_classify(change):
def on_click(change):
    img = PILImage.create(btn_upload.data[-1])
    out_pl.clear_output()
    with out_pl: display(img.to_thumb(128,128))
    pred,pred_idx,probs = learn_inf.predict(img)
    lbl_pred.value = f'Prediction: {pred}; Probability: {probs[pred_idx]:.04f}'

#btn_run.on_click(on_click_classify)

# %%
#hide
#Putting back btn_upload to a widget for next cell
# test btn_upload = widgets.FileUpload()

# %%
btn_upload.observe(on_click, names=['data'])

# %%
#hide_output
display(VBox([widgets.Label('Selecione seu peixe!'), 
      btn_upload, out_pl, lbl_pred]))
#but_run
